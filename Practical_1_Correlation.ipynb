# %% [markdown]
# <a href="https://colab.research.google.com/github/aryansuri42/Reinforcement-learning-21csu467/blob/main/Practical_1_Correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import random
l1 = [random.randint(x,100) for x in range(0,100)]
l2 = [random.randint(x,100) for x in range(0,100)]
plt.scatter(l1,l2)

# %%
l3 = [x for x in range(0,12)]
l4 = [x+12 for x in range(0,12)]

l5 = [abs(x-12) for x in range(0,12)]
plt.subplot(1,2,1)
plt.scatter(l3,l4)
plt.subplot(1,2,2)
plt.scatter(l3,l5)

# %%
import numpy as np

arr1 = np.array(l1)
arr2 = np.array(l2)

rel = np.corrcoef(arr1,arr2)

print(rel)
plt.plot(rel)
# Out:
# [[ 1.         -0.18124707]
#  [-0.18124707  1.        ]]
# [<matplotlib.lines.Line2D at 0x790244c90be0>,
#  <matplotlib.lines.Line2D at 0x790244c90d90>]

# %%
arr1 = np.array(np.random.randint((1000), size=(500)))
arr2 = np.array(np.random.choice((arr1*57), size=(500)))
arr3 = np.array(np.random.choice((-(arr1*75)), size=(500)))
arr4 = np.array(np.random.randint((1000), size=(500)))
plt.figure(figsize=(10,7))
plt.subplot(1,2,1)
plt.scatter(arr1,arr2)
plt.subplot(1,2,2)
plt.scatter(arr1,arr3)

# %%
rel = np.corrcoef(arr1,arr2)
print(rel)
plt.plot(rel)
# Out:
# [[1.         0.03986205]
#  [0.03986205 1.        ]]
# [<matplotlib.lines.Line2D at 0x79022d4bccd0>,
#  <matplotlib.lines.Line2D at 0x79022d4bcd30>]

# %%
import pandas as pd

df = pd.DataFrame({"A":arr1, "B":arr2, "C":arr3, "D":arr4})

df
# Out:
#        A      B      C    D
# 0    716  45714 -48750  639
# 1    512  38019 -67050  484
# 2    749  56316 -74775  853
# 3    373   3876 -38475  369
# 4    356   3021 -30225  610
# ..   ...    ...    ...  ...
# 495  823  28272  -7200  706
# 496   31   3363   -750  907
# 497  965  37050 -24075  140
# 498  518  32661 -34350  912
# 499  526  20862 -18075  167
#
# [500 rows x 4 columns]

# %%
corr = df.corr(method='pearson')
corr
# Out:
#           A         B         C         D
# A  1.000000  0.039862 -0.073003  0.033607
# B  0.039862  1.000000 -0.113363 -0.030133
# C -0.073003 -0.113363  1.000000  0.012964
# D  0.033607 -0.030133  0.012964  1.000000
